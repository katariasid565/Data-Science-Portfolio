# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Customer_Segmentation_py.csv")
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  26/11/2013   26  November  2013            19     Youth (<25)
# 1  26/11/2015   26  November  2015            19     Youth (<25)
# 2  23/03/2014   23     March  2014            49  Adults (35-64)
# 3  23/03/2016   23     March  2016            49  Adults (35-64)
# 4  15/05/2014   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %%
df.shape
# Out:
# (113036, 18)

# %%
category_df = df.groupby('Product_Category')[['Sub_Category']].count().reset_index()
category_df
# Out:
#   Product_Category  Sub_Category
# 0      Accessories         70120
# 1            Bikes         25982
# 2         Clothing         16934

# %%
state_df = df.groupby('State')[['Profit','Cost','Revenue']].sum().reset_index()
state_df
# Out:
#                   State   Profit     Cost   Revenue
# 0               Alabama      105      105       210
# 1               Alberta    23350    33453     56803
# 2               Arizona     4279     5100      9379
# 3                Bayern   576691   765294   1341985
# 4           Brandenburg    71352    98418    169770
# 5      British Columbia  3693348  4184542   7877890
# 6            California  7772869  9899751  17672620
# 7     Charente-Maritime    46000    60047    106047
# 8               England  4413853  6232343  10646196
# 9               Essonne   393848   579684    973532
# 10              Florida     4700     6314     11014
# 11      Garonne (Haute)    72947   110959    183906
# 12              Georgia     1947     2915      4862
# 13              Hamburg   616499   942506   1559005
# 14       Hauts de Seine   364137   573003    937140
# 15               Hessen   813402  1259989   2073391
# 16             Illinois     8606    11535     20141
# ...

# %%
gender_df = df.groupby('Customer_Gender').count()
gender_df
# Out:
#                   Date    Day  Month   Year  Customer_Age  Age_Group  Country  \
# Customer_Gender
# F                54724  54724  54724  54724         54724      54724    54724
# M                58312  58312  58312  58312         58312      58312    58312
#
#                  State  Product_Category  Sub_Category  Product  \
# Customer_Gender
# F                54724             54724         54724    54724
# M                58312             58312         58312    58312
#
#                  Order_Quantity  Unit_Cost  Unit_Price  Profit   Cost  Revenue
# Customer_Gender
# F                         54724      54724       54724   54724  54724    54724
# M                         58312      58312       58312   58312  58312    58312
